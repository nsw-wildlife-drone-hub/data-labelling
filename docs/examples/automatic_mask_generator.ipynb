# %% [markdown]
# <a href="https://colab.research.google.com/github/nsw-wildlife-drone-hub/data-labelling/blob/main/docs/examples/automatic_mask_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Automatically generating object masks with SAM
#
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeos/segment-geospatial/blob/main/docs/examples/automatic_mask_generator.ipynb)
# [![image](https://img.shields.io/badge/Open-Planetary%20Computer-black?style=flat&logo=microsoft)](https://pccompute.westeurope.cloudapp.azure.com/compute/hub/user-redirect/git-pull?repo=https://github.com/opengeos/segment-geospatial&urlpath=lab/tree/segment-geospatial/docs/examples/automatic_mask_generator.ipynb&branch=main)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/segment-geospatial/blob/main/docs/examples/automatic_mask_generator.ipynb)
#
# This notebook shows how to segment objects from an image using the Segment Anything Model (SAM) with a few lines of code.
#
# Make sure you use GPU runtime for this notebook. For Google Colab, go to `Runtime` -> `Change runtime type` and select `GPU` as the hardware accelerator.
#
# The notebook is adapted from [segment-anything/notebooks/automatic_mask_generator_example.ipynb](https://github.com/opengeos/segment-anything/blob/pypi/notebooks/automatic_mask_generator_example.ipynb), but I have made it much easier to save the segmentation results and visualize them.

# %% [markdown]
# ## Install dependencies
#
# Uncomment and run the following cell to install the required dependencies.

# %%
# %pip install segment-geospatial leafmap localtileserver
# Out:
# Collecting segment-geospatial
#   Downloading segment_geospatial-0.10.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting leafmap
#   Downloading leafmap-0.36.5-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver
#   Downloading localtileserver-0.10.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (5.1.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (0.14.4)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (0.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (3.7.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.10.0.84)
# Collecting patool (from segment-geospatial)
#   Downloading patool-2.3.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2.0.8)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (3.6.1)
# Collecting rasterio (from segment-geospatial)
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting segment-anything-hq (from segment-geospatial)
#   Downloading segment_anything_hq-0.3-py3-none-any.whl.metadata (17 kB)
# Collecting segment-anything-py (from segment-geospatial)
#   Downloading segment_anything_py-1.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting timm (from segment-geospatial)
#   Downloading timm-1.0.8-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (4.66.5)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2024.6.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from segment-geospatial) (2024.6.0)
# Collecting anywidget>=0.9.13 (from leafmap)
#   Downloading anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: bqplot>=0.12.43 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.12.43)
# Requirement already satisfied: colour>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.1.5)
# Requirement already satisfied: duckdb>=0.10.3 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.10.3)
# Requirement already satisfied: folium>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.17.0)
# Collecting geojson>=3.1.0 (from leafmap)
#   Downloading geojson-3.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from leafmap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.18.2 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.18.2)
# Collecting ipyvuetify>=1.9.4 (from leafmap)
#   Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.6.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (7.7.1)
# Requirement already satisfied: numpy<3.0.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (1.26.4)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from leafmap) (2.1.4)
# Requirement already satisfied: plotly>=5.15.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (5.15.0)
# Requirement already satisfied: pyshp>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from leafmap) (2.3.1)
# Collecting pystac-client>=0.8.2 (from leafmap)
#   Downloading pystac_client-0.8.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: python-box>=7.2.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (7.2.0)
# Requirement already satisfied: scooby>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from leafmap) (0.10.0)
# Collecting whiteboxgui>=2.3.0 (from leafmap)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from localtileserver) (8.1.7)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from localtileserver) (2.2.5)
# Collecting Flask-Caching (from localtileserver)
#   Downloading Flask_Caching-2.3.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver)
#   Downloading Flask_Cors-4.0.1-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-restx>=0.5.0 (from localtileserver)
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver)
#   Downloading rio_tiler-6.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver)
#   Downloading rio_cogeo-5.3.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from localtileserver) (2.32.3)
# Collecting server-thread (from localtileserver)
#   Downloading server_thread-0.2.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.10/dist-packages (from localtileserver) (3.0.3)
# Collecting psygnal>=0.8.1 (from anywidget>=0.9.13->leafmap)
#   Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from anywidget>=0.9.13->leafmap) (4.12.2)
# Requirement already satisfied: traitlets>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from bqplot>=0.12.43->leafmap) (5.7.1)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from bqplot>=0.12.43->leafmap) (0.2.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask<4,>=2.0.0->localtileserver) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask<4,>=2.0.0->localtileserver) (2.2.0)
# Collecting aniso8601>=0.82 (from flask-restx>=0.5.0->localtileserver)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (4.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (2024.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from flask-restx>=0.5.0->localtileserver) (6.4.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium>=0.14.0->leafmap) (0.7.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->segment-geospatial) (3.15.4)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify>=1.9.4->leafmap)
#   Downloading ipyvue-1.11.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap) (3.6.8)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.0->leafmap) (3.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->segment-geospatial) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->leafmap) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.15.0->leafmap) (9.0.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client>=0.8.2->leafmap)
#   Downloading pystac-1.10.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->localtileserver) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug->localtileserver) (2.1.5)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.10/dist-packages (from whiteboxgui>=2.3.0->leafmap) (0.2.2)
# Collecting whitebox (from whiteboxgui>=2.3.0->leafmap)
#   Downloading whitebox-2.3.5-py2.py3-none-any.whl.metadata (10 kB)
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching->localtileserver)
#   Downloading cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: fiona>=1.8.21 in /usr/local/lib/python3.10/dist-packages (from geopandas->segment-geospatial) (1.9.6)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from geopandas->segment-geospatial) (2.0.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->segment-geospatial) (6.0.2)
# Collecting affine (from rasterio->segment-geospatial)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->segment-geospatial)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->segment-geospatial) (71.0.4)
# Collecting morecantile<6.0,>=5.0 (from rio-cogeo->localtileserver)
#   Downloading morecantile-5.3.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.10/dist-packages (from rio-cogeo->localtileserver) (2.8.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver) (5.4.0)
# Collecting color-operations (from rio-tiler->localtileserver)
#   Downloading color_operations-0.1.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting httpx (from rio-tiler->localtileserver)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from rio-tiler->localtileserver) (2.10.1)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from segment-anything-hq->segment-geospatial) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.8 in /usr/local/lib/python3.10/dist-packages (from segment-anything-hq->segment-geospatial) (0.18.1+cu121)
# Collecting uvicorn (from server-thread->localtileserver)
#   Downloading uvicorn-0.30.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->segment-geospatial) (0.4.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas->segment-geospatial) (1.16.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->leafmap) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->leafmap) (6.3.3)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (2.20.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->flask-restx>=0.5.0->localtileserver) (0.20.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->segment-anything-hq->segment-geospatial) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->segment-anything-hq->segment-geospatial) (3.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->segment-anything-hq->segment-geospatial) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7->segment-anything-hq->segment-geospatial)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (6.5.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->segment-geospatial) (2.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver) (3.7.1)
# Collecting httpcore==1.* (from httpx->rio-tiler->localtileserver)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->rio-tiler->localtileserver) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->rio-tiler->localtileserver)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6.0->leafmap) (0.2.13)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->rio-tiler->localtileserver) (1.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->segment-anything-hq->segment-geospatial) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (4.2.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (4.9.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (2.20.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (21.2.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->leafmap) (1.8.0)
# Downloading segment_geospatial-0.10.6-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 1.8 MB/s eta 0:00:00
# Downloading leafmap-0.36.5-py2.py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.7/474.7 kB 22.7 MB/s eta 0:00:00
# Downloading localtileserver-0.10.3-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 74.5 MB/s eta 0:00:00
# Downloading anywidget-0.9.13-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 15.5 MB/s eta 0:00:00
# Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 72.8 MB/s eta 0:00:00
# Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 73.3 MB/s eta 0:00:00
# Downloading pystac_client-0.8.3-py3-none-any.whl (33 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.1 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.0-py3-none-any.whl (28 kB)
# Downloading Flask_Cors-4.0.1-py2.py3-none-any.whl (14 kB)
# Downloading patool-2.3.0-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 8.0 MB/s eta 0:00:00
# Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 22.0 MB/s eta 0:00:00
# Downloading rio_cogeo-5.3.3-py3-none-any.whl (20 kB)
# Downloading rio_tiler-6.6.1-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.5/263.5 kB 13.1 MB/s eta 0:00:00
# Downloading segment_anything_hq-0.3-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.0 MB/s eta 0:00:00
# Downloading segment_anything_py-1.0.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.6 MB/s eta 0:00:00
# Downloading server_thread-0.2.0-py3-none-any.whl (8.5 kB)
# Downloading timm-1.0.8-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 57.3 MB/s eta 0:00:00
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.7 MB/s eta 0:00:00
# Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Downloading ipyvue-1.11.1-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 80.4 MB/s eta 0:00:00
# Downloading morecantile-5.3.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.5 MB/s eta 0:00:00
# Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 45.5 MB/s eta 0:00:00
# Downloading pystac-1.10.1-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 16.1 MB/s eta 0:00:00
# Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading color_operations-0.1.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.2/186.2 kB 17.5 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.4 MB/s eta 0:00:00
# Downloading uvicorn-0.30.5-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.1 MB/s eta 0:00:00
# Downloading whitebox-2.3.5-py2.py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 7.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: aniso8601, whitebox, snuggs, psygnal, patool, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jedi, h11, geojson, color-operations, cachelib, affine, uvicorn, rasterio, pystac, nvidia-cusparse-cu12, nvidia-cudnn-cu12, httpcore, server-thread, nvidia-cusolver-cu12, morecantile, httpx, flask-cors, Flask-Caching, rio-tiler, rio-cogeo, flask-restx, pystac-client, localtileserver, timm, segment-anything-py, segment-anything-hq, ipyvue, anywidget, whiteboxgui, ipyvuetify, leafmap, segment-geospatial
# Successfully installed Flask-Caching-2.3.0 affine-2.4.0 aniso8601-9.0.1 anywidget-0.9.13 cachelib-0.9.0 color-operations-0.1.5 flask-cors-4.0.1 flask-restx-1.3.0 geojson-3.1.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 ipyvue-1.11.1 ipyvuetify-1.10.0 jedi-0.19.1 leafmap-0.36.5 localtileserver-0.10.3 morecantile-5.3.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 patool-2.3.0 psygnal-0.11.1 pystac-1.10.1 pystac-client-0.8.3 rasterio-1.3.10 rio-cogeo-5.3.3 rio-tiler-6.6.1 segment-anything-hq-0.3 segment-anything-py-1.0.1 segment-geospatial-0.10.6 server-thread-0.2.0 snuggs-1.4.7 timm-1.0.8 uvicorn-0.30.5 whitebox-2.3.5 whiteboxgui-2.3.0

# %%
import os
import leafmap
from samgeo import SamGeo, show_image, download_file, overlay_images, tms_to_geotiff

# %% [markdown]
# ## Create an interactive map

# %%
m = leafmap.Map(center=[-34.326, 142.345], zoom=17, height="800px")
m.add_basemap("Esri.WorldImagery") #Esri.WorlImagery SATELLITE
m
# Out:
# Map(center=[-34.326, 142.345], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %% [markdown]
# Pan and zoom the map to select the area of interest. Use the draw tools to draw a polygon or rectangle on the map

# %%
if m.user_roi_bounds() is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-122.2659, 37.8682, -122.2521, 37.8741]

# %% [markdown]
# ## Download a sample image

# %%
image = "satellite.tif"
tms_to_geotiff(output=image, bbox=bbox, zoom=17, source="Satellite", overwrite=True)
# Out:
# Downloaded image 001/150
# Downloaded image 002/150
# Downloaded image 003/150
# Downloaded image 004/150
# Downloaded image 005/150
# Downloaded image 006/150
# Downloaded image 007/150
# Downloaded image 008/150
# Downloaded image 009/150
# Downloaded image 010/150
# Downloaded image 011/150
# Downloaded image 012/150
# Downloaded image 013/150
# Downloaded image 014/150
# Downloaded image 015/150
# Downloaded image 016/150
# Downloaded image 017/150
# Downloaded image 018/150
# Downloaded image 019/150
# Downloaded image 020/150
# Downloaded image 021/150
# Downloaded image 022/150
# Downloaded image 023/150
# Downloaded image 024/150
# Downloaded image 025/150
# Downloaded image 026/150
# Downloaded image 027/150
# Downloaded image 028/150
# Downloaded image 029/150
# Downloaded image 030/150
# Downloaded image 031/150
# Downloaded image 032/150
# Downloaded image 033/150
# Downloaded image 034/150
# Downloaded image 035/150
# Downloaded image 036/150
# Downloaded image 037/150
# Downloaded image 038/150
# Downloaded image 039/150
# Downloaded image 040/150
# Downloaded image 041/150
# Downloaded image 042/150
# Downloaded image 043/150
# Downloaded image 044/150
# Downloaded image 045/150
# Downloaded image 046/150
# Downloaded image 047/150
# Downloaded image 048/150
# Downloaded image 049/150
# Downloaded image 050/150
# Downloaded image 051/150
# Downloaded image 052/150
# Downloaded image 053/150
# Downloaded image 054/150
# Downloaded image 055/150
# Downloaded image 056/150
# Downloaded image 057/150
# Downloaded image 058/150
# Downloaded image 059/150
# Downloaded image 060/150
# Downloaded image 061/150
# Downloaded image 062/150
# Downloaded image 063/150
# Downloaded image 064/150
# Downloaded image 065/150
# Downloaded image 066/150
# Downloaded image 067/150
# Downloaded image 068/150
# Downloaded image 069/150
# Downloaded image 070/150
# Downloaded image 071/150
# Downloaded image 072/150
# Downloaded image 073/150
# Downloaded image 074/150
# Downloaded image 075/150
# Downloaded image 076/150
# Downloaded image 077/150
# Downloaded image 078/150
# Downloaded image 079/150
# Downloaded image 080/150
# Downloaded image 081/150
# Downloaded image 082/150
# Downloaded image 083/150
# Downloaded image 084/150
# Downloaded image 085/150
# Downloaded image 086/150
# Downloaded image 087/150
# Downloaded image 088/150
# Downloaded image 089/150
# Downloaded image 090/150
# Downloaded image 091/150
# Downloaded image 092/150
# Downloaded image 093/150
# Downloaded image 094/150
# Downloaded image 095/150
# Downloaded image 096/150
# Downloaded image 097/150
# Downloaded image 098/150
# Downloaded image 099/150
# Downloaded image 100/150
# Downloaded image 101/150
# Downloaded image 102/150
# Downloaded image 103/150
# Downloaded image 104/150
# Downloaded image 105/150
# Downloaded image 106/150
# Downloaded image 107/150
# Downloaded image 108/150
# Downloaded image 109/150
# Downloaded image 110/150
# Downloaded image 111/150
# Downloaded image 112/150
# Downloaded image 113/150
# Downloaded image 114/150
# Downloaded image 115/150
# Downloaded image 116/150
# Downloaded image 117/150
# Downloaded image 118/150
# Downloaded image 119/150
# Downloaded image 120/150
# Downloaded image 121/150
# Downloaded image 122/150
# Downloaded image 123/150
# Downloaded image 124/150
# Downloaded image 125/150
# Downloaded image 126/150
# Downloaded image 127/150
# Downloaded image 128/150
# Downloaded image 129/150
# Downloaded image 130/150
# Downloaded image 131/150
# Downloaded image 132/150
# Downloaded image 133/150
# Downloaded image 134/150
# Downloaded image 135/150
# Downloaded image 136/150
# Downloaded image 137/150
# Downloaded image 138/150
# Downloaded image 139/150
# Downloaded image 140/150
# Downloaded image 141/150
# Downloaded image 142/150
# Downloaded image 143/150
# Downloaded image 144/150
# Downloaded image 145/150
# Downloaded image 146/150
# Downloaded image 147/150
# Downloaded image 148/150
# Downloaded image 149/150
# Downloaded image 150/150
# Saving GeoTIFF. Please wait...
# Image saved to satellite.tif

# %% [markdown]
# You can also use your own image. Uncomment and run the following cell to use your own image.

# %%
# image = '/path/to/your/own/image.tif'

# %% [markdown]
# Display the downloaded image on the map.

# %%
m.layers[-1].visible = False
m.add_raster(image, layer_name="Image")
m
# Out:
# Map(bottom=5047290.0, center=[-34.32655, 142.34654999999998], controls=(ZoomControl(options=['position', 'zoom…

# %% [markdown]
# ## Initialize SAM class
#
# Specify the file path to the model checkpoint. If it is not specified, the model will to downloaded to the working directory.

# %%
sam = SamGeo(
    model_type="vit_h",
    sam_kwargs=None,
)

# %% [markdown]
# ## Automatic mask generation
#
# Segment the image and save the results to a GeoTIFF file. Set `unique=True` to assign a unique ID to each object.

# %%
sam.generate(image, output="masks.tif", foreground=True, unique=True)

# %%
sam.show_masks(cmap="binary_r")

# %% [markdown]
# Show the object annotations (objects with random color) on the map.

# %%
sam.show_anns(axis="off", alpha=1, output="annotations.tif")

# %% [markdown]
# Compare images with a slider.

# %%
leafmap.image_comparison(
    "satellite.tif",
    "annotations.tif",
    label1="Satellite Image",
    label2="Image Segmentation",
)

# %% [markdown]
# Add image to the map.

# %%
m.add_raster("annotations.tif", alpha=0.5, layer_name="Masks")
m

# %% [markdown]
# Convert the object annotations to vector format, such as GeoPackage, Shapefile, or GeoJSON.

# %%
sam.tiff_to_vector("masks.tif", "masks.gpkg")

# %% [markdown]
# ## Automatic mask generation options
#
# There are several tunable parameters in automatic mask generation that control how densely points are sampled and what the thresholds are for removing low quality or duplicate masks. Additionally, generation can be automatically run on crops of the image to get improved performance on smaller objects, and post-processing can remove stray pixels and holes. Here is an example configuration that samples more masks:

# %%
sam_kwargs = {
    "points_per_side": 32,
    "pred_iou_thresh": 0.86,
    "stability_score_thresh": 0.92,
    "crop_n_layers": 1,
    "crop_n_points_downscale_factor": 2,
    "min_mask_region_area": 100,
}

# %%
sam = SamGeo(
    model_type="vit_h",
    sam_kwargs=sam_kwargs,
)

# %%
sam.generate(image, output="masks2.tif", foreground=True)

# %%
sam.show_masks(cmap="binary_r")

# %%
sam.show_anns(axis="off", opacity=1, output="annotations2.tif")

# %% [markdown]
# Compare images with a slider.

# %%
leafmap.image_comparison(
    image,
    "annotations.tif",
    label1="Image",
    label2="Image Segmentation",
)

# %% [markdown]
# Overlay the annotations on the image and use the slider to change the opacity interactively.

# %%
overlay_images(image, "annotations2.tif", backend="TkAgg")

# %% [markdown]
# ![](https://i.imgur.com/I1IhDgz.gif)
